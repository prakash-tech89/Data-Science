# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
file_path=r"C:\Users\Praku\Week 13 Statistics\data-for-datavis"
cancer_b_df=pd.read_csv(file_path+"\cancer_b.csv",index_col='Id')
cancer_m_df=pd.read_csv(file_path+"\cancer_m.csv",index_col='Id')

# %%
len(cancer_b_df)
# Out:
# 357

# %%
len(cancer_m_df)
# Out:
# 212

# %%
cancer_b_df.isna().sum()
# Out:
# Diagnosis                    0
# Radius (mean)                0
# Texture (mean)               0
# Perimeter (mean)             0
# Area (mean)                  0
# Smoothness (mean)            0
# Compactness (mean)           0
# Concavity (mean)             0
# Concave points (mean)        0
# Symmetry (mean)              0
# Fractal dimension (mean)     0
# Radius (se)                  0
# Texture (se)                 0
# Perimeter (se)               0
# Area (se)                    0
# Smoothness (se)              0
# Compactness (se)             0
# Concavity (se)               0
# Concave points (se)          0
# Symmetry (se)                0
# Fractal dimension (se)       0
# Radius (worst)               0
# Texture (worst)              0
# Perimeter (worst)            0
# Area (worst)                 0
# Smoothness (worst)           0
# Compactness (worst)          0
# Concavity (worst)            0
# Concave points (worst)       0
# Symmetry (worst)             0
# ...

# %%
cancer_m_df.isna().sum()
# Out:
# Diagnosis                    0
# Radius (mean)                0
# Texture (mean)               0
# Perimeter (mean)             0
# Area (mean)                  0
# Smoothness (mean)            0
# Compactness (mean)           0
# Concavity (mean)             0
# Concave points (mean)        0
# Symmetry (mean)              0
# Fractal dimension (mean)     0
# Radius (se)                  0
# Texture (se)                 0
# Perimeter (se)               0
# Area (se)                    0
# Smoothness (se)              0
# Compactness (se)             0
# Concavity (se)               0
# Concave points (se)          0
# Symmetry (se)                0
# Fractal dimension (se)       0
# Radius (worst)               0
# Texture (worst)              0
# Perimeter (worst)            0
# Area (worst)                 0
# Smoothness (worst)           0
# Compactness (worst)          0
# Concavity (worst)            0
# Concave points (worst)       0
# Symmetry (worst)             0
# ...

# %%
cancer_b_df.describe().transpose()
# Out:
#                            count        mean         std         min  \
# Radius (mean)              357.0   12.146524    1.780512    6.981000
# Texture (mean)             357.0   17.914762    3.995125    9.710000
# Perimeter (mean)           357.0   78.075406   11.807438   43.790000
# Area (mean)                357.0  462.790196  134.287118  143.500000
# Smoothness (mean)          357.0    0.092478    0.013446    0.052630
# Compactness (mean)         357.0    0.080085    0.033750    0.019380
# Concavity (mean)           357.0    0.046058    0.043442    0.000000
# Concave points (mean)      357.0    0.025717    0.015909    0.000000
# Symmetry (mean)            357.0    0.174186    0.024807    0.106000
# Fractal dimension (mean)   357.0    0.062867    0.006747    0.051850
# Radius (se)                357.0    0.284082    0.112570    0.111500
# Texture (se)               357.0    1.220380    0.589180    0.360200
# Perimeter (se)             357.0    2.000321    0.771169    0.757000
# ...

# %%
cancer_m_df.describe().T
# Out:
#                            count         mean         std         min  \
# Radius (mean)              212.0    17.462830    3.203971   10.950000
# Texture (mean)             212.0    21.604906    3.779470   10.380000
# Perimeter (mean)           212.0   115.365377   21.854653   71.900000
# Area (mean)                212.0   978.376415  367.937978  361.600000
# Smoothness (mean)          212.0     0.102898    0.012608    0.073710
# Compactness (mean)         212.0     0.145188    0.053987    0.046050
# Concavity (mean)           212.0     0.160775    0.075019    0.023980
# Concave points (mean)      212.0     0.087990    0.034374    0.020310
# Symmetry (mean)            212.0     0.192909    0.027638    0.130800
# Fractal dimension (mean)   212.0     0.062680    0.007573    0.049960
# Radius (se)                212.0     0.609083    0.345039    0.193800
# Texture (se)               212.0     1.210915    0.483178    0.362100
# ...

# %%
fig=plt.figure(figsize=(20,34))
ax1 = fig.add_subplot(10,3,1)
ax2 = fig.add_subplot(10,3,2)
ax3 = fig.add_subplot(10,3,3)
ax4 = fig.add_subplot(10,3,4)
ax5 = fig.add_subplot(10,3,5)
ax6 = fig.add_subplot(10,3,6)
ax7 = fig.add_subplot(10,3,7)
ax8 = fig.add_subplot(10,3,8)
ax9 = fig.add_subplot(10,3,9)
ax10 = fig.add_subplot(10,3,10)
ax11 = fig.add_subplot(10,3,11)
ax12 = fig.add_subplot(10,3,12)
ax13 = fig.add_subplot(10,3,13)
ax14 = fig.add_subplot(10,3,14)
ax15 = fig.add_subplot(10,3,15)
ax16 = fig.add_subplot(10,3,16)
ax17 = fig.add_subplot(10,3,17)
ax18 = fig.add_subplot(10,3,18)
ax19 = fig.add_subplot(10,3,19)
ax20 = fig.add_subplot(10,3,20)
ax21 = fig.add_subplot(10,3,21)
ax22 = fig.add_subplot(10,3,22)
ax23 = fig.add_subplot(10,3,23)
ax24 = fig.add_subplot(10,3,24)
ax25 = fig.add_subplot(10,3,25)
ax26 = fig.add_subplot(10,3,26)
ax27 = fig.add_subplot(10,3,27)
ax28 = fig.add_subplot(10,3,28)
ax29 = fig.add_subplot(10,3,29)
ax30 = fig.add_subplot(10,3,30)


# Tell pointplot to plot on ax1 with the ax argument (satisfaction level)
sns.distplot(cancer_b_df['Radius (mean)'],ax = ax1)
sns.distplot(cancer_b_df['Radius (se)'],ax = ax2)
sns.distplot(cancer_b_df['Radius (worst)'],ax = ax3)
sns.distplot(cancer_b_df['Texture (mean)'],ax = ax4)
sns.distplot(cancer_b_df['Texture (se)'],ax = ax5)
sns.distplot(cancer_b_df['Texture (worst)'],ax = ax6)
sns.distplot(cancer_b_df['Perimeter (mean)'],ax = ax7)
sns.distplot(cancer_b_df['Perimeter (se)'],ax = ax8)
sns.distplot(cancer_b_df['Perimeter (worst)'],ax = ax9)
sns.distplot(cancer_b_df['Area (mean)'],ax = ax10)
sns.distplot(cancer_b_df['Area (se)'],ax = ax11)
sns.distplot(cancer_b_df['Area (worst)'],ax = ax12)
sns.distplot(cancer_b_df['Smoothness (mean)'],ax = ax13)
sns.distplot(cancer_b_df['Smoothness (se)'],ax = ax14)
sns.distplot(cancer_b_df['Smoothness (worst)'],ax = ax15)
sns.distplot(cancer_b_df['Compactness (mean)'],ax = ax16)
sns.distplot(cancer_b_df['Compactness (se)'],ax = ax17)
sns.distplot(cancer_b_df['Compactness (worst)'],ax = ax18)
sns.distplot(cancer_b_df['Concavity (mean)'],ax = ax19)
sns.distplot(cancer_b_df['Concavity (se)'],ax = ax20)
sns.distplot(cancer_b_df['Concavity (worst)'],ax = ax21)
sns.distplot(cancer_b_df['Concave points (mean)'],ax = ax22)
sns.distplot(cancer_b_df['Concave points (se)'],ax = ax23)
sns.distplot(cancer_b_df['Concave points (worst)'],ax = ax24)
sns.distplot(cancer_b_df['Symmetry (mean)'],ax = ax25)
sns.distplot(cancer_b_df['Symmetry (se)'],ax = ax26)
sns.distplot(cancer_b_df['Symmetry (worst)'],ax = ax27)
sns.distplot(cancer_b_df['Fractal dimension (mean)'],ax = ax28)
sns.distplot(cancer_b_df['Fractal dimension (se)'],ax = ax29)
sns.distplot(cancer_b_df['Fractal dimension (worst)'],ax = ax30)

# %%
fig=plt.figure(figsize=(20,34))
ax1 = fig.add_subplot(10,3,1)
ax2 = fig.add_subplot(10,3,2)
ax3 = fig.add_subplot(10,3,3)
ax4 = fig.add_subplot(10,3,4)
ax5 = fig.add_subplot(10,3,5)
ax6 = fig.add_subplot(10,3,6)
ax7 = fig.add_subplot(10,3,7)
ax8 = fig.add_subplot(10,3,8)
ax9 = fig.add_subplot(10,3,9)
ax10 = fig.add_subplot(10,3,10)
ax11 = fig.add_subplot(10,3,11)
ax12 = fig.add_subplot(10,3,12)
ax13 = fig.add_subplot(10,3,13)
ax14 = fig.add_subplot(10,3,14)
ax15 = fig.add_subplot(10,3,15)
ax16 = fig.add_subplot(10,3,16)
ax17 = fig.add_subplot(10,3,17)
ax18 = fig.add_subplot(10,3,18)
ax19 = fig.add_subplot(10,3,19)
ax20 = fig.add_subplot(10,3,20)
ax21 = fig.add_subplot(10,3,21)
ax22 = fig.add_subplot(10,3,22)
ax23 = fig.add_subplot(10,3,23)
ax24 = fig.add_subplot(10,3,24)
ax25 = fig.add_subplot(10,3,25)
ax26 = fig.add_subplot(10,3,26)
ax27 = fig.add_subplot(10,3,27)
ax28 = fig.add_subplot(10,3,28)
ax29 = fig.add_subplot(10,3,29)
ax30 = fig.add_subplot(10,3,30)


# Tell pointplot to plot on ax1 with the ax argument (satisfaction level)
sns.distplot(cancer_m_df['Radius (mean)'],ax = ax1)
sns.distplot(cancer_m_df['Radius (se)'],ax = ax2)
sns.distplot(cancer_m_df['Radius (worst)'],ax = ax3)
sns.distplot(cancer_m_df['Texture (mean)'],ax = ax4)
sns.distplot(cancer_m_df['Texture (se)'],ax = ax5)
sns.distplot(cancer_m_df['Texture (worst)'],ax = ax6)
sns.distplot(cancer_m_df['Perimeter (mean)'],ax = ax7)
sns.distplot(cancer_m_df['Perimeter (se)'],ax = ax8)
sns.distplot(cancer_m_df['Perimeter (worst)'],ax = ax9)
sns.distplot(cancer_m_df['Area (mean)'],ax = ax10)
sns.distplot(cancer_m_df['Area (se)'],ax = ax11)
sns.distplot(cancer_m_df['Area (worst)'],ax = ax12)
sns.distplot(cancer_m_df['Smoothness (mean)'],ax = ax13)
sns.distplot(cancer_m_df['Smoothness (se)'],ax = ax14)
sns.distplot(cancer_m_df['Smoothness (worst)'],ax = ax15)
sns.distplot(cancer_m_df['Compactness (mean)'],ax = ax16)
sns.distplot(cancer_m_df['Compactness (se)'],ax = ax17)
sns.distplot(cancer_m_df['Compactness (worst)'],ax = ax18)
sns.distplot(cancer_m_df['Concavity (mean)'],ax = ax19)
sns.distplot(cancer_m_df['Concavity (se)'],ax = ax20)
sns.distplot(cancer_m_df['Concavity (worst)'],ax = ax21)
sns.distplot(cancer_m_df['Concave points (mean)'],ax = ax22)
sns.distplot(cancer_m_df['Concave points (se)'],ax = ax23)
sns.distplot(cancer_m_df['Concave points (worst)'],ax = ax24)
sns.distplot(cancer_m_df['Symmetry (mean)'],ax = ax25)
sns.distplot(cancer_m_df['Symmetry (se)'],ax = ax26)
sns.distplot(cancer_m_df['Symmetry (worst)'],ax = ax27)
sns.distplot(cancer_m_df['Fractal dimension (mean)'],ax = ax28)
sns.distplot(cancer_m_df['Fractal dimension (se)'],ax = ax29)
sns.distplot(cancer_m_df['Fractal dimension (worst)'],ax = ax30)

# %%
corr_b = cancer_b_df.drop(['Diagnosis'],axis=1).corr()
plt.figure(figsize=(20,15))

plt.title("Cancer attributes for B")

sns.heatmap(corr_b,annot=True)

plt.xlabel("Cancer attribute for B-Type")
# Out:
# Text(0.5, 114.0, 'Cancer attribute for B-Type')

# %% [markdown]
# Above heat map depicts strong relationship (+ve covariance in the range of 0.90 to 1 ) between Radius , perimeter and Area. Also Medium relationship (+ve covariance in the range of 0.80 to 0.90) between Compactness and Concavity . between Compactness , Concave points,symmetry and fractal dimension (+ve covariance in the range of 0.70 to 0.80). Smoothness and fractal dimension also (+ve covariance in the range of 0.70 to 0.80). No significant relationship for Texture
#
# 0.90 to 1:
#
# Radius <-> Perimeter (1)
# Radius <-> Area (.99)
# Perimeter <-> Area(.99)
#
# 0.75 to 0.80
#
# Compactness <-> concativity (0.75)
#
# 0.65 to 0.75
#
# Compactness <-> Concave points(.75)
# Compactness<-> Symmetry(.38)
# Compactness <-> Fractal dimension(.69)
#
# 0.65 to 0.70
#
# Compactness<-> Fractal dimension(.69)
# smoothness<-> Fractal dimension(.56)

# %%
cancer_b_df.cov()
# Out:
#                            Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Radius (mean)                   3.170222       -0.264260         20.955350
# Texture (mean)                 -0.264260       15.961021         -1.883254
# Perimeter (mean)               20.955350       -1.883254        139.415582
# Area (mean)                   237.769160      -20.952647       1570.766840
# Smoothness (mean)              -0.004432       -0.012560         -0.023613
# Compactness (mean)              0.003632       -0.007914          0.053962
# Concavity (mean)                0.006711       -0.004006          0.075716
# Concave points (mean)           0.011666       -0.009059          0.087444
# Symmetry (mean)                -0.010405       -0.006809         -0.061204
# Fractal dimension (mean)       -0.006409       -0.002401         -0.038203
# Radius (se)                    -0.005564        0.046990         -0.014150
# ...

# %% [markdown]
# With Covarriance , we see strengh of relationship exist between following attributes
#
# Radius(mean) <-> Perimeter (~20)
# Radius(mean <-> Area (~237)
# +Area(mean) <-> perimeter (~1570)
#
# Area(worst)<-> Perimeter(mean) 1862
# Area(Worst)<-> Area(Mean) (21414)
# Area(worst)<-> Perimeter(worst) (2159)
# Area(Worst)<-> Area(se) 566
# Area(Worst)<-> Radius(mean) 281
# Area(Worst)<-> Radius(worst) 321

# %%
corr_m = cancer_m_df.drop(['Diagnosis'],axis=1).corr()
plt.figure(figsize=(20,15))

plt.title("Cancer attributes for M")

sns.heatmap(corr_m,annot=True)

plt.xlabel("Cancer attribute for M-Type")
# Out:
# Text(0.5, 114.0, 'Cancer attribute for M-Type')

# %% [markdown]
# Above heat map depicts strong relationship (+ve covariance in the range of 0.90 to 1 ) between Radius , perimeter and Area. Also Medium relationship (+ve covariance in the range of 0.80 to 0.90) between Compactness and Concavity . between Compactness , Concave points,symmetry and fractal dimension (+ve covariance in the range of 0.70 to 0.80). Smoothness and fractal dimension also (+ve covariance in the range of 0.70 to 0.80). No significant relationship for Texture
#
# 0.90 to 1:
#
# Radius <-> Perimeter (1)
# Radius <-> Area (.99)
# Perimeter <-> Area(.99)
#
# 0.80 to 0.90
#
# Compactness <-> concativity (0.85)
#
# 0.75 to 0.80
#
# Compactness <-> Concave points(.73)
# Compactness<-> Symmetry(.7)
# Compactness <-> Fractal dimension(.76)
#
# 0.70 to 0.70
#
# Smoothness<-> Fractal dimension(.75)

# %%
cancer_m_df.cov()
# Out:
#                            Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Radius (mean)                  10.265431        1.289841         69.691279
# Texture (mean)                  1.289841       14.284393          9.142258
# Perimeter (mean)               69.691279        9.142258        477.625870
# Area (mean)                  1167.166503      144.246922       7938.413279
# Smoothness (mean)              -0.004687       -0.006858         -0.014439
# Compactness (mean)              0.029262        0.006645          0.302531
# Concavity (mean)                0.116034        0.019035          0.909925
# Concave points (mean)           0.074397        0.002267          0.548517
# Symmetry (mean)                -0.006769       -0.009402         -0.008655
# Fractal dimension (mean)       -0.009431       -0.001762         -0.051899
# Radius (se)                     0.706709        0.050442          4.932246
# ...

# %% [markdown]
# With Covarriance , we see strengh of relationship exist between following attributes
#
# Perimeter(mean) <-> Radius (mean) 69
# Area(mean) <-> Radius(mean) 1161
# Area(mean) <-> Texture(mean) 143
# Area(mean) <-> Perimeter(mean) 7900
#
# Radius(se) <-> Area (mean) 86
# Perimeter(se) <-> Perimeter (mean) 36
# Perimeter(se) <-> Area(mean) 630
#
# Area(se) <-> Radius(mean) 135
# Area(se)<-> Perimeter(mean) 940
# Area(se)<-> Area(mean) 16955
# Area(se)<-> Perimeter(se) 146
#
#
# Perimeter(worst) <-> Perimeter(mean) 590
# Perimeter(worst) <-> Area(mean) 9878
# Perimeter(worst) <-> Area(se) 1286
# Perimeter(worst) <-> Radius(worst) 123
#
# Area(worst) <-> Radius(mean) 1704
# Area(worst) <-> Texture(mean) 284
# Area(worst) <-> Perimeter(mean) 11563
# Area(worst) <-> Area(mean) 199574
# Area(worst) <-> Area(se) 27435
# Area(worst) <-> Radius(worst) 2513
# Area(worst) <-> Texture(worst) 100
# Area(worst) <-> Perimeter(worst) 17023

# %%
cancer_df=pd.concat([cancer_b_df,cancer_m_df])

# %%
len(cancer_df)
# Out:
# 569

# %%
cancer_df[cancer_df.columns[0:11]]
# Out:
#           Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426           B         13.540           14.36             87.46
# 8510653           B         13.080           15.71             85.63
# 8510824           B          9.504           12.44             60.34
# 854941            B         13.030           18.42             82.61
# 85713702          B          8.196           16.84             51.71
# 857155            B         12.050           14.63             78.04
# 857156            B         13.490           22.30             86.91
# 857343            B         11.760           21.60             74.72
# 857373            B         13.640           16.34             87.21
# 857374            B         11.940           18.24             75.71
# 85759902          B         11.520           18.75             73.34
# 857810            B         13.050           19.31             82.61
# ...

# %%
cancer_df['Diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: Diagnosis, dtype: int64

# %%
#fig=plt.figure(figsize=(15,35))

#sns.set_context("paper", font_scale=3, rc={"font.size":8,"axes.labelsize":5})
sns.reset_orig()
fig=sns.pairplot(cancer_df[cancer_df.columns[0:11]],hue='Diagnosis',height=1.8)
# Out:
# C:\Users\Praku\Anaconda3\lib\site-packages\matplotlib\__init__.py:855: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# C:\Users\Praku\Anaconda3\lib\site-packages\matplotlib\__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)
