# %%
import pandas as pd

# %%
train=pd.read_csv("Train_UWu5bXk.csv")

# %%
train.shape
# Out:
# (8523, 12)

# %%
train.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.1+ KB

# %%
train.sample(n=10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3873           FDU56        16.85               LF         0.044414
# 4087           FDE28         9.50          Regular         0.000000
# 243            FDY56        16.35          Regular         0.062764
# 1442           FDM57        11.65          Regular         0.075849
# 1282           DRG51        12.10          Low Fat         0.011605
# 8328           FDI57        19.85          Low Fat         0.054246
# 5467           FDF10        15.50              reg         0.156798
# 3928           FDW13          NaN          Low Fat         0.097411
# 6057           DRA59          NaN          Regular         0.127308
# 2702           FDH19          NaN          Low Fat         0.057934
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3873  Fruits and Vegetables  182.4266            OUT046
# 4087           Frozen Foods  228.4668            OUT049
# ...

# %%
train.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
train[train.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
# %matplotlib inline
#train.Item_Weight.plot(kind='bar')

# %%
# %matplotlib inline
train.Outlet_Size.value_counts().plot(kind='pie')

# %%
train.sample(n=10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7432           FDU47       12.800          Regular         0.190569
# 6883           NCE54          NaN          Low Fat         0.047098
# 3535           FDT59       13.650          Low Fat         0.015976
# 7147           FDD32       17.700              reg         0.041164
# 4907           FDC03        8.575          Regular         0.072253
# 4583           FDB05          NaN          Low Fat         0.145670
# 6285           FDW12        8.315          Regular         0.035572
# 593            FDR36        6.715          Regular         0.121485
# 3248           FDR25       17.000          Regular         0.139805
# 7532           FDO58          NaN          Low Fat         0.039386
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7432                 Breads  138.7838            OUT010
# 6883              Household   75.5354            OUT019
# ...

# %%
train.Item_Weight.isna().sum()
# Out:
# 1463

# %%
train['Item_Weight'].fillna(train.Item_Weight.mean(),inplace=True)
train.Item_Weight.mean()
# Out:
# 12.857645184136409

# %%
train.Item_Weight.isna().sum()
# Out:
# 0

# %%
train.sample(n=10)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5366           FDC26    10.195000          Low Fat         0.211539
# 6886           FDX13    12.857645          Low Fat         0.047552
# 2615           FDJ55    12.857645          Regular         0.023417
# 2476           NCE54    12.857645          Low Fat         0.026770
# 4735           FDL14     8.115000          Regular         0.032159
# 2564           FDJ26    15.300000          Regular         0.084749
# 5860           FDB33    12.857645          Low Fat         0.025528
# 7430           NCO42    21.250000          Low Fat         0.024694
# 8286           NCP06    20.700000          Low Fat         0.039307
# 8302           FDY20    12.500000          Regular         0.082215
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 5366                 Canned  110.9886            OUT010
# 6886                 Canned  249.1092            OUT027
# ...

# %%
train.Outlet_Size.isna().sum()
# Out:
# 2410

# %%
train['Outlet_Size'].fillna(train.Outlet_Size.mode()[0],inplace=True)

# %%
train.Outlet_Size.isna().sum()
# Out:
# 0

# %%
import numpy as np
train.loc[train.Item_Visibility==0,'Item_Visibility']=np.nan
train.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15     9.300000          Low Fat         0.016047
# 1           DRC01     5.920000          Regular         0.019278
# 2           FDN15    17.500000          Low Fat         0.016760
# 3           FDX07    19.200000          Regular              NaN
# 4           NCD19     8.930000          Low Fat              NaN
# 5           FDP36    10.395000          Regular              NaN
# 6           FDO10    13.650000          Regular         0.012741
# 7           FDP10    12.857645          Low Fat         0.127470
# 8           FDH17    16.200000          Regular         0.016687
# 9           FDU28    19.200000          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
cat_col=train.select_dtypes(exclude=np.number).columns
cat_col
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
num_col=train.select_dtypes(include=np.number).columns
num_col
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
cat_col_without_id=[i for i in cat_col if i not in ('Item_Identifier','Outlet_Identifier')]
cat_col_without_id
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
for i in cat_col_without_id:
    print(i,train[i].unique())
# Out:
# Item_Fat_Content ['Low Fat' 'Regular']
# Item_Type ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# Outlet_Size ['Medium' 'High' 'Small']
# Outlet_Location_Type ['Tier 1' 'Tier 3' 'Tier 2']
# Outlet_Type ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %%
train.replace({'low fat':'Low Fat','LF':'Low Fat','reg':'Regular'},inplace=True)
for i in cat_col_without_id:
    print(i,train[i].unique())
# Out:
# Item_Fat_Content ['Low Fat' 'Regular']
# Item_Type ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# Outlet_Size ['Medium' 'High' 'Small']
# Outlet_Location_Type ['Tier 1' 'Tier 3' 'Tier 2']
# Outlet_Type ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %%
cat_col_ordinal=[i for i in cat_col_without_id if i in ('Outlet_Size','Item_Fat_Content')]
cat_col_nominal=[i for i in cat_col_without_id if i not in ('Outlet_Size','Item_Fat_Content')]
print(cat_col_ordinal,cat_col_nominal)
# Out:
# ['Item_Fat_Content', 'Outlet_Size'] ['Item_Type', 'Outlet_Location_Type', 'Outlet_Type']

# %%
one_hot_encode_df=pd.get_dummies(train,columns=['Item_Fat_Content','Outlet_Size'])
one_hot_encode_df
# Out:
#      Item_Identifier  Item_Weight  Item_Visibility              Item_Type  \
# 0              FDA15     9.300000         0.016047                  Dairy
# 1              DRC01     5.920000         0.019278            Soft Drinks
# 2              FDN15    17.500000         0.016760                   Meat
# 3              FDX07    19.200000              NaN  Fruits and Vegetables
# 4              NCD19     8.930000              NaN              Household
# 5              FDP36    10.395000              NaN           Baking Goods
# 6              FDO10    13.650000         0.012741            Snack Foods
# 7              FDP10    12.857645         0.127470            Snack Foods
# 8              FDH17    16.200000         0.016687           Frozen Foods
# 9              FDU28    19.200000         0.094450           Frozen Foods
# 10             FDY07    11.800000              NaN  Fruits and Vegetables
# 11             FDA03    18.500000         0.045464                  Dairy
# ...

# %%
#df_one_hot_encoded=pd.concat([train[train.columns-cat_col_ordinal],one_hot_encode_df],axis=1)
#df_one_hot_encoded
one_hot_encode_df.shape
# Out:
# (8523, 15)

# %%
cat_col_nominal
# Out:
# ['Item_Type', 'Outlet_Location_Type', 'Outlet_Type']

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_y=LabelEncoder()
df_label_encoded=train.apply(labelencoder_y.fit_transform)
df_label_encoded
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                 156          284                 0              663
# 1                   8           57                 1              879
# 2                 662          376                 0              714
# 3                1121          393                 1             8095
# 4                1297          265                 0             8000
# 5                 758          297                 1             8016
# 6                 696          334                 1              394
# 7                 738          326                 0             6770
# 8                 440          363                 1              706
# 9                 990          393                 1             5780
# 10               1171          314                 0             7996
# 11                147          386                 1             3163
# ...
